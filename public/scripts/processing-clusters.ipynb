# %%
# generate graph data for clustered vectors from '/Volumes/Storage/Programming/dissertation-research/apps/opentext/public/data/graphData/clusters_top-edges-only-nofilter.json'

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse

def generateCosineSimilaritiesUsingSKLearn(vectors):
    vectorsWithoutHeaders = vectors[1:]
    vectorIds = [vector[0] for vector in vectorsWithoutHeaders]
    vectorsWithoutStageId = [vector[1:] for vector in vectorsWithoutHeaders]
    numpy_string_vectors = np.array(vectorsWithoutStageId)
    numpy_vectors = numpy_string_vectors.astype(np.float)
    sparse_vectors = sparse.csr_matrix(numpy_vectors)
    similarities = cosine_similarity(sparse_vectors)
    similarities_trimmed = [value[0:2] for value in similarities]
    # Add IDs back into vector array
    similaritiesWithIds = []
    for count, vector in enumerate(similarities):
        similaritiesWithIds.append([str(vectorIds[count]), *[round(value,2) for value in vector]])
    return similaritiesWithIds

def sumVectorsFromCluster(listOfVectorsToCombine):
    vectorsWithoutIDs = [vector[1:] for vector in listOfVectorsToCombine]
    numpy_string_vectors = np.array(vectorsWithoutIDs)
    vectorLabels = [vector[0] for vector in listOfVectorsToCombine]
    numpy_vectors = numpy_string_vectors.astype(np.float)
    outputVector = [int(value) for value in numpy_vectors[0]]
    for vector in numpy_vectors[1:]:
        outputVector = np.add(outputVector, vector)
    return (vectorLabels, outputVector)

# %%
# Map cluster numbers from gephi export to xml file for episodes
import json
with open('/Users/ryderwishart/gephi-data/temporally-sequenced-similarities-modular-83-all-nodes-included.json', encoding='utf-8') as inputFile:
    clusterDictionary = json.load(inputFile)
nodes = clusterDictionary['nodes']

from lxml import etree
with open('/Volumes/Storage/Programming/dissertation-research/python/episodes-ranges.xml', encoding='utf-8') as episodeXMLFile:
    episodeTree = etree.parse(episodeXMLFile)
episodes = episodeTree.xpath("//episode")

print('number of nodes', len(nodes))
print('number of episodes', len(episodes))

count = 0
matchDict = dict()
for node in nodes:
    nodeID = '-'.join(node['label'].split('§')).split(' ')[0]
    for episode in episodes:
        episodeID = (episode.attrib['section']).split(' ')[0]
        if nodeID == episodeID:
            matchDict[nodeID] = episodeID
            episode.attrib['cluster'] = ''
            episode.attrib['cluster'] = node['attributes']['modularity_class']
            count += 1
print(count)
print(len(matchDict.keys()))
for node in nodes:
    if node not in list(matchDict.keys()):
        print('missing', node['label'])
    # episode.attrib['cluster'] =
# Out:
# number of nodes 282
# number of episodes 627
# 267
# 267
# missing 02§30 The Last Discourses of Christ in Galilee
# missing 03§61 The Lord’s Third Prediction of His Passion
# missing 01§24 The Call of Matthew and His Feast
# missing 01§34 The Woe upon the Galilean Cities
# missing 03§72a The Walk to Gethsemane and the Agony
# missing 01§88b Events at Gethsemane
# missing 04§14 The Feeding of the Five Thousand
# missing 03§66b Parable of the Wicked Tenants
# missing 01§33 Christ’s Testimony Concerning John
# missing 01§63 01§64 The Reward of the Apostles; Parable of the Laborers in the Vineyard
# missing 03§39 03§40 Christ Casts Out a Demon and Rebukes The Generation
# missing 03§77 03§78 The Emmaus Disciples and the Last Appearances of Christ
# missing 02§46 The Capture of Jesus
# missing 04§12 04§13 Jesus Defends Himself Against Jews Persecuting Him
# missing 02§33 The Rich Young Man
# missing 02§39 The Parable of the Vineyard
# missing 03§12 The Beginning of Christ’s Ministry and His Teaching in Nazareth
# missing 02§52 The Resurrection of Jesus
# missing 02§49a Jesus before Pilate
# missing 04§33 Jesus Reveals His Betrayor
# missing 01§20 The Discipleship of Christ
# missing 02§08 Healing the Withered Hand
# missing 02§45b Jesus Prays in Gethsemane
# missing 01§05 The Ministry of John the Baptist
# missing 04§45 04§46 The Trial Before Pilate
# missing 03§45 The Crippled Woman Healed
# missing 01§42a The Parable of the Tares; and Others
# missing 01§50 The Demand for a Sign
# missing 01§18 The Centurion of Capernaum
# missing 02§29 Casting Out an Unclean Spirit
# missing 03§34b True Discipleship of Christ
# missing 02§44a The Preparation for the Passover
# missing 01§39 The Sign from Heaven and a Warning
# missing 03§03 The Annunciation to Mary
# missing 01§90a The Trial before Caiaphas
# missing 01§56a Christ Foretells His Passion
# missing 02§12 Christ Stilling the Tempest
# missing 03§02b Elizabeth Conceives
# missing 03§67 The Pharisees Confounded
# missing 01§67 Healing of Two Blind Men
# missing 03§50 03§51 03§52 03§53 03§54 Parables and Teaching
# missing 03§02a The Announcement of John the Baptist’s Birth
# missing 02§01 The Ministry of John the Baptist
# missing 03§08 The Christ-Child in the Temple
# missing 04§09b The Samaritans Believe
# missing 02§04 The Healing of a Leper
# missing 02§14 Raising of the Daughter of Jairus
# missing 03§37 Mary and Martha
# missing 04§25a Jesus Hears of Lazarus
# missing 01§25 The Daughter of Jairus
# missing 02§45a Jesus Predicts Peter's Denials
# missing 04§09a Christ and the Woman of Samaria
# missing 04§47b The Soldiers Divide Jesus's Clothes
# missing 02§13 The Healing of a Demon-Possessed Man
# missing 03§41 Woes upon the Pharisees and Lawyers
# missing 01§74 The Parable of the Marriage Feast
# missing 02§28 The Transfiguration of Jesus
# missing 01§36b The Lord of the Sabbath - Healing
# missing 03§59 Christ Blesses Little Children
# missing 02§50 Jesus before the Soldiers
# missing 01§86d Judas Bargains for Jesus
# missing 04§16 04§17 Christ the Bread of Life
# missing 02§11b Teaching the Disciples by Means of Parables
# missing 03§09 The Ministry of John the Baptist
# missing 03§34a Opposition in Samaria
# missing 04§03 John Meets Jesus
# missing 03§56 Concerning the Kingdom of God and the Coming of Christ
# missing 01§88a On the Way to Gethsemane
# missing 04§18c Jesus at the Festival
# missing 01§06 The Baptism of Jesus
# missing 04§19 The Woman Taken in Adultery
# missing 03§32 The Healing of the Epileptic Boy
# missing 01§08b The Call of the Four
# missing 01§22 Jesus and the Gadarenes
# missing 02§43a The Teachers of the Law Scheme
# missing 03§24 Teaching in Parables
# missing 04§34 04§35 04§36 04§37 04§38 04§39 04§40 04§41 Jesus Teaches at the Last Supper
# missing 01§81 01§82 01§83 01§84 01§85 The Judgment of God upon Jerusalem and upon the World; The Need of Watchfulness; The Parable of the Ten Virgins; The Parable of the Talents; The Last Judgment
# missing 02§27a The Identity of the Son of Man
# missing 02§50 The Crucifixion and Death of Christ
# missing 02§07a New Wine into Old Wineskins
# missing 02§11a The Parable of the Sower
# missing 02§15 Jesus at Nazareth
# missing 02§44b The Celebration of the Passover
# missing 01§78 01§79 01§80 The Inordinate Ambition of the Pharisees; The Woes upon the Hypocrisy of the Pharisees; The Peroration and the Lament over Jerusalem
# missing 01§09 01§10 01§11 01§12 01§13 01§14 01§15 01§16 The Beatitudes; The Chief Functions of the Disciples in the World; Christ Confirms and Expounds the Law of Moses; The Law of Love toward the Enemy; On Giving of Alms; Praying; and Fasting; Warning against Covetousness and Care; Warning against Unauthorized Judging and Admonition to Persevere in Prayer; The Conclusion of the Sermon
# missing 03§15 The Healing of a Leper
# missing 03§73a The Denial of Peter
# missing 01§69 Christ Visits the Temple
# missing 01§46 Christ Walks on the Sea
# missing 03§05 The Birth of John the Baptist and Zechariah's Song
# missing 03§76 The Resurrection of Christ
# missing 04§26 The Council concerning Christ’s Removal
# missing 02§38 The Question concerning Christ’s Authority
# missing 04§01 The Word Became Flesh
# missing 04§10 The Healing of the Nobleman’s Son
# missing 01§44 The Death of John the Baptist
# missing 04§50 The Appearance to the Hidden Disciples
# missing 01§92 The Trial before Pilate
# missing 01§95b The Soldiers Bribed to Silence
# missing 01§42b The Parable of the Tares; and Others Explained
# missing 03§20 The Centurion of Capernaum
# missing 01§49 Christ Teaches and Feeds Four Thousand
# missing 01§23 The Healing of the Palsied Man
# missing 03§65b Christ’s Entry into Jerusalem
# missing 04§44b The High Priest Questions Jesus
# missing 02§22 The Syrophoenician Woman
# missing 02§03b Jesus Prays in a Solitary Place
# missing 04§47a The Jews Protest Pilate's Sign
# missing 01§91 The End of Judas
# missing 02§43b The Anointing of Jesus
# missing 03§46a Few Are Saved
# missing 03§24 Jesus Mother and Brothers
# missing 02§36 Christ’s Entry into Jerusalem
# missing 01§71 01§72 01§73 The Authority of Christ; The Parable of the Two Sons; The Parable of the Wicked Husbandmen
# missing 04§50 The Appearance to Thomas
# missing 01§90b The Denial of Peter
# missing 01§70 The Cursing of the Fig-Tree
# missing 01§04 The Flight into Egypt and the Return to Nazareth
# missing 04§23 Jesus the Good Shepherd
# missing 01§48 The Syrophoenician Woman
# missing 03§75a The Crucifixion and Death of Christ
# missing 01§95a The Resurrection of Christ
# missing 04§47c Jesus Entrusts His Mother and Dies
# missing 03§65a Jesus Procures a Donkey
# missing 01§62 The Dangers of Riches
# missing 02§25 The Leaven of the Pharisees
# missing 03§21 Raising of the Widow’s Son
# missing 04§27 The Anointing of Jesus
# missing 01§54 The Transfiguration of Christ
# missing 02§18 The Feeding of the Five Thousand
# missing 01§45 The Feeding of the Five Thousand
# missing 01§32 John the Baptist’s Disciples Come to Jesus
# missing 03§36 The Good Samaritan
# missing 02§40c The Greatest Commandment
# missing 03§11 The Temptation of Christ
# missing 01§52 “Christ the Son of the Living God”
# missing 03§42 03§43 03§44 The Teaching of the Kingdom
# missing 03§62 The Blind Man of Jericho
# missing 01§36a The Lord of the Sabbath - Food
# missing 04§25c Jesus at the Tomb of Lazarus
# missing 01§55 The Healing of a Boy with a Demon
# missing 04§44c Peter's Second and Third Denials
# missing 01§94 The Burial of Christ
# missing 03§25 The Storm on the Sea
# missing 03§30 Peter’s Confession and Christ’s Answer
# missing 01§57 01§58 01§59 The Greatest in the Kingdom of Heaven; How to Deal with an Erring Brother; Parable of the Unmerciful Servant
# missing 04§51 The Appearance of Christ at the Sea of Tiberias
# missing 03§22 The Embassy of John the Baptist
# missing 01§35 The Gospel Call
# missing 03§17 Disputes Concerning Sabbath Observance
# missing 03§64 The Parable of the Talents
# missing 01§76 The Question of the Sadducees
# missing 02§24 The Feeding of the Four Thousand
# missing 01§26 Further Miracles of That Day
# missing 02§10b Discourse on the Casting Out of Demons
# missing 03§68 Devouring Widows Houses
# missing 01§37 01§38 The Enmity of the Pharisees and Christ’s Answer; The Sin against the Holy Spirit
# missing 01§86c A Woman Anoints Jesus
# missing 02§40b The Sadducees Question Jesus About the Resurrection
# missing 04§43 The Arrest of Jesus
# missing 02§05 Healing the Palsied Man
# missing 03§13b Jesus Heals Many
# missing 03§67 The Sadducees Confounded
# missing 02§31 A Question concerning Divorce
# missing 04§18a The Unbelief of Christ’s Brothers
# missing 02§02a The Baptism and Temptation of Christ
# missing 01§87a The Passover Meal
# missing 04§04b Jesus Calls Philip and Nathaniel
# missing 02§19 Christ Walking on the Sea and His Return to Galilee
# missing 02§20 02§21 Concerning Ceremonial Washings; Christ’s Denunciation of the Pharisees
# missing 01§28 01§29 01§30 01§31 The Commission to the Twelve; The Perils of Apostleship; Fearless Confession of Christ Demanded; Perfect Consecration to Christ
# missing 03§33 Lessons in Humility
# missing 03§73b The Guards Mistreat Jesus
# missing 02§47 The Trial before the High Priest
# missing 01§77 The Silencing of the Pharisees
# missing 01§68 Christ’s Entry into Jerusalem
# missing 01§89 The Betrayal and Arrest
# missing 01§21 The Storm on the Lake
# missing 01§40 Christ’s Relatives
# missing 03§35 The Mission of the Seventy
# missing 01§86a Jesus Predicts Crucifixion
# missing 01§66 The Requests of the Sons of Zebedee
# missing 02§09 Miracles by the Seaside
# missing 04§18b Jesus Is Sought at the Festival
# missing 03§66a The Authority of Jesus
# missing 02§23 Healing of the Deaf Man
# missing 04§42 Christ’s Great Sacerdotal Prayer
# missing 03§28a The Mission of the Twelve
# missing 03§46b Some Pharisees Warn Jesus
# missing 01§56b Christ Pays the Temple-Tax
# missing 02§41 Jesus Condemns the Teachers of the Law
# missing 03§14 The Miraculous Draught of Fishes and the Call of the First Disciples
# missing 02§02b The Beginning of His Ministry
# missing 02§37 The Miracle of the Fig-Tree
# missing 03§47 03§48 Christ the Guest of a Pharisee
# missing 03§74 The Trial before Pilate
# missing 04§04a The First Disciples of Jesus
# missing 01§08a The Beginning of the Galilean Ministry
# missing 01§86e Jesus Gives Instructions for Supper
# missing 01§96 The Great Missionary Command
# missing 04§26 Many Seek Jesus at the Festival
# missing 02§25 The Pharisees Ask for a Sign
# missing 03§16 The Call of Levi and the Discourse Concerning Christ’s Ministry
# missing 03§29 The Feeding of the Five Thousand
# missing 04§25b Martha Confronts Jesus
# missing 03§23 The First Anointing of Jesus
# missing 04§15 Christ Walks on the Sea
# missing 03§72b Jesus Arrested
# missing 01§27 Continuation of Christ’s Teaching and Healing Ministry
# missing 01§51 The Leaven of the Pharisees
# missing 02§06 The Calling of Levi and the Dinner at His House
# missing 04§08 John’s Second Testimony of Christ
# missing 03§26 In the Country of the Gadarenes
# missing 01§61 Christ Blessing Little Children
# missing 03§60 Denying All for Christ’s Sake
# missing 01§60 On Marriage and Divorce
# missing 01§47 A Lesson Concerning Defilement
# missing 03§06b The Adoration of the Shepherds
# missing 03§31 The Transfiguration
# missing 02§03a Ministry in Capernaum
# missing 01§41a The Parable of the Sower
# missing 04§18d The Jewish Elites Disbelieve
# missing 03§07 The Circumcision and Presentation of Christ
# missing 02§32 Jesus Blesses Little Children
# missing 04§06 The Purging of the Temple and Its Results
# missing 04§49 Easter Morning
# missing 03§04 Mary’s Visit to Elizabeth
# missing 04§20 04§21 Jesus the Light of the World
# missing 01§17 The Healing of the Leper
# missing 04§28 Christ’s Entry into Jerusalem
# missing 01§93 The Crucifixion and Death of Christ
# missing 04§44a Peter's First Denial
# missing 03§38 A Lesson in Prayer
# missing 01§65 Christ Again Foretells His Passion
# missing 02§48 The Denial of Peter
# missing 03§10a The Baptism of Christ
# missing 03§28b Herod Hears about Jesus
# missing 01§75 The Question Concerning Tribute
# missing 01§86b Leaders Conspire
# missing 01§02 The Annunciation to Joseph and the Birth of Jesus
# missing 03§69 The Destruction of Jerusalem and the End of the World
# missing 04§07 The Visit of Nicodemus
# missing 02§17 Death of John the Baptist
# missing 03§49 The Obligations of Christ’s Discipleship
# missing 03§55 The Ten Lepers
# missing 04§24b Jesus Returns to the Other Side of the Jordan
# missing 04§32 Jesus Washes the Disciples' Feet
# missing 02§34a Jesus Turns Toward Jerusalem
# missing 01§87b The Institution of the Lord’s Supper
# missing 04§02 The Pharisees Question John the Baptist
# missing 03§58 The Pharisee and the Publican
# missing 04§24a Christ’s Sermon at the Feast of Dedication
# missing 01§53 Christ’s First Prophecy Concerning His Passion
# missing 02§16 The Mission of the Twelve
# missing 03§71 The Preparation for; and the Celebration of; the Passover
# missing 02§49b Pilate before the Crowd
# missing 04§05 The Marriage at Cana
# missing 03§63 Zacchaeus the Publican
# missing 03§57 The Unjust Judge
# missing 02§34b Priority in Christ’s Kingdom
# missing 03§19 Miracles of Healing and Preaching
# missing 01§07 The Temptation in the Wilderness
# missing 04§29 04§30 04§31 Some Greeks Seek Jesus but Many Disbelieve
# missing 04§52 The Test of Peter’s Love
# missing 02§27b Jesus the Christ and His Service
# missing 04§22 Healing of the Man That was Born Blind
# missing 02§53 The Appearances and the Ascension of Jesus
# missing 01§03 The Wise Men from the East
# missing 02§07b The Lord of the Sabbath
# missing 02§40a The Pharisees and Herodians Ask About Paying Taxes to Caesar
# missing 02§35 The Healing of Bartimaeus
# missing 01§41b The Parable of the Sower Explained
# missing 01§43 A Visit to Nazareth
# missing 03§27 The Woman with an Issue and the Daughter of Jairus
# missing 02§42 Christ Foretells the Destruction of Jerusalem and the End of the World
# missing 03§65c Cleansing the Temple
# missing 02§26 The Blind Man of Bethsaida
# missing 04§11 The Sick Man of Bethesda
# missing 03§13a Healing of a Demoniac
# missing 03§73c Christ before the Council of the Elders
# missing 03§15 The Healing of a Paralytic

# %%
with open('episodes-ranges-update.xml', 'a', encoding='utf-8') as out:
    for episode in episodes:
        out.write(f'{etree.tostring(episode)}\n')

# %%
# create a lookup table of which node ids belong in which clusters
clusterDict = {str(number): [node['id'] for node in nodes if node['attributes']['modularity_class'] == str(number)] for number in range(0,59)}

# %%
def generateNodeFromCosineSimilarities(cosineSimilaritiesRow):
    cells = cosineSimilaritiesRow.split(',')
    id = cells[0]
    label = cells[0]
    averageSimilarity = sum([float(cell) for cell in cells[1:]]) / len(cells[1:])
    nodeFields = (id, label, averageSimilarity)
    node = '\t'.join([str(field) for field in nodeFields])
    return node

def generateEdgesFromCosineSimilarities(columnHeaders, cosineSimilaritiesRow):
    # 'ID\tSOURCE\tTARGET\tWEIGHT\n'
    cells = cosineSimilaritiesRow.split(',')
    edges = []
    columnHeadersWithoutIDColumn = columnHeaders[1:]
    source = cells[0]
    for count, cell in enumerate(cells):
        if count == 0:
            pass
        else:
            cell = cells[count]
            if float(cell) > 0:
                target = columnHeaders[count]
                if target == source:
                    pass
                else:
                    # edgesSets.append(targetAndSource)
                    edge = (f'{source}-{target}', source, target, cell)
                    edgeString = '\t'.join(edge)
                    if len(edgeString.split('\t')) != 4:
                        print('FAIL', edgeString.split('\t'))
                    edges.append(edgeString)
    return edges

def generateTopEdgesFromCosineSimilarities(columnHeaders, cosineSimilaritiesRow):
    # 'ID\tSOURCE\tTARGET\tWEIGHT\n'
    cells = cosineSimilaritiesRow.split(',')
    edges = []
    edgeTuples = []
    columnHeadersWithoutIDColumn = columnHeaders[1:]
    source = cells[0]
    for count, cell in enumerate(cells):
        if count == 0:
            pass
        else:
            cell = cells[count]
            if float(cell) > 0:
                target = columnHeaders[count]
                if target == source:
                    pass
                else:
                    # edgesSets.append(targetAndSource)
                    # edge = (f'{source}-{target}', source, target, cell)
                    # edgeString = '\t'.join(edge)
                    # if len(edgeString.split('\t')) != 4:
                        # print('FAIL', edgeString.split('\t'))
                    edgeTuples.append((source,target,float(cell)))
    edgeTuples.sort(key=lambda edgeTuple: edgeTuple[2])
    topEdgeValue = edgeTuples[-1]
    topEdges = [edge for edge in edgeTuples if edge[2] == topEdgeValue[2] ]
    edges = ['\t'.join((f'{edge[0]}-{edge[1]}', edge[0], edge[1], str(edge[2]))) for edge in topEdges]
    return edges

# %%
# Generate cluster-based cosine similarities

inputFilePath = '/Volumes/Storage/Programming/dissertation-research/python/all-dynamic-features-vectors-gospels.tsv'

nodes = []
edges = []

with open(inputFilePath, 'r', encoding='utf8') as featuresCSVData:
    with open('cluster-cosineValues.tsv', 'a', encoding='utf-8') as outputFile:
        featuresData = [line for line in featuresCSVData]
        columnHeaders = featuresData[0].split(',')
        
        vectorsByCluster = {str(number): [line.strip().split(',') for line in featuresData if line.split(',')[0] in clusterDict[str(number)]] for number in range(0,59)} 
        clusterVectors = []
        for count in range(0,59):

            vectorLabels, combinedVector = sumVectorsFromCluster(vectorsByCluster[str(count)])
            labels = ';'.join(vectorLabels)
            vectorWithID = [f'{count} {labels}', *combinedVector]
            clusterVectors.append(vectorWithID)
        
            numberOfTextsInCluster = len(vectorsByCluster[str(count)])
            node = f'{count}\tCluster {count}\t{numberOfTextsInCluster}\t{vectorLabels}'
            nodes.append(node)
        similarities = generateCosineSimilaritiesUsingSKLearn(clusterVectors)
        
        for line in similarities:
            outputFile.write(line[0] + ',')
        
        for line in similarities:
            print(line)
            outputData = [str(value) for value in line]
            outputFile.write(','.join(outputData))
            outputFile.write('\n')
            # rowEdges = generateTopEdgesFromCosineSimilarities(columnHeaders, line)
            # for edge in rowEdges:
            #     cells = edge.split('\t')
            #     targetAndSourceArray = [
            #         cells[2], 
            #         cells[1]
            #     ]
            #     if targetAndSourceArray[0] != targetAndSourceArray[1]:
            #         targetAndSource = set(targetAndSourceArray)
            #         pairIndex = '-'.join(targetAndSource)
            #         edgesDict[pairIndex] = edge
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-03aefa624aa1> in <module>()
#      15         for count in range(0,59):
#      16
# ---> 17             vectorLabels, combinedVector = sumVectorsFromCluster(vectorsByCluster[str(count)])
#      18             labels = ';'.join(vectorLabels)
#      19             vectorWithID = [f'{count} {labels}', *combinedVector]
#
# <ipython-input-1-2f72501cf0b8> in sumVectorsFromCluster(listOfVectorsToCombine)
#      25     vectorLabels = [vector[0] for vector in listOfVectorsToCombine]
#      26     numpy_vectors = numpy_string_vectors.astype(np.float)
# ---> 27     outputVector = [int(value) for value in numpy_vectors[0]]
#      28     for vector in numpy_vectors[1:]:
#      29         outputVector = np.add(outputVector, vector)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
def generateEdgesFromCosineSimilarities(columnHeaders, cosineSimilaritiesRow):
    # 'ID\tSOURCE\tTARGET\tWEIGHT\n'
    cells = cosineSimilaritiesRow.split(',')
    print('CELLS:', cells)
    edges = []
    columnHeadersWithoutIDColumn = columnHeaders[1:]
    source = cells[0]
    for count, cell in enumerate(cells):
        if count == 0:
            pass
        else:
            cell = cells[count]
            if float(cell) > 0:
                target = columnHeaders[count]
                if target == source:
                    pass
                else:
                    # edgesSets.append(targetAndSource)
                    edge = (f'{source}-{target}', source, target, cell)
                    edgeString = '\t'.join(edge)
                    if len(edgeString.split('\t')) != 4:
                        print('FAIL', edgeString.split('\t'))
                    edges.append(edgeString)
    return edges

def generateClusterNodeFromCosineSimilarities(cosineSimilaritiesRow):
    cells = cosineSimilaritiesRow.split(',')
    id = cells[0]
    label = cells[0]
    averageSimilarity = sum([float(cell) for cell in cells[1:]]) / len(cells[1:])
    
    nodeFields = (id, label, averageSimilarity)
    
    node = '\t'.join([str(field) for field in nodeFields])
    return node

# %%
# Generate cluster-based cosine graph data
cosineSimilaritiesInputFilePath = '/Volumes/Storage/Programming/dissertation-research/python/cluster-cosineValues.tsv'

nodes = []
edges = []
edgesDict = dict()
with open(cosineSimilaritiesInputFilePath, 'r', encoding='utf8') as cosineCSVData:
    isFirstRow = True
    for line in cosineCSVData:
        if isFirstRow:
            columnHeaders = line.split(',')
            isFirstRow = False
        else:
            node = generateClusterNodeFromCosineSimilarities(line)
            nodes.append(node)
            rowEdges = generateEdgesFromCosineSimilarities(columnHeaders, line)
            for edge in rowEdges:
                cells = edge.split('\t')
                targetAndSourceArray = [
                    cells[2], 
                    cells[1]
                ]
                if targetAndSourceArray[0] != targetAndSourceArray[1]:
                    targetAndSource = set(targetAndSourceArray)
                    pairIndex = '-'.join(targetAndSource)
                    edgesDict[pairIndex] = edge

with open('nodes_clusters.tsv', 'a', encoding='utf8') as nodeFile:
    nodeFile.write('id\tlabel\taverage_similarity\n')
    for node in nodes:
        nodeFile.write(node)
        nodeFile.write('\n')
with open('edges_clusters.tsv', 'a', encoding='utf8') as edgeFile:
    edgeFile.write('id\tsource\ttarget\tweight\n')
    # for edge in prunedEdges:
    for count,edgePair in enumerate(edgesDict):
        edgeFile.write(edgesDict[edgePair])
        edgeFile.write('\n')
# Out:
# .75', '0.6', '0.72', '0.82', '0.55', '0.7', '1.0', '0.9', '0.81', '0.91', '0.89', '0.85', '0.68', '0.73', '0.62', '0.53', '0.84', '0.54', '0.65', '0.71', '0.76', '0.6', '0.5', '0.47', '0.83', '0.58', '0.87', '0.76', '0.74', '0.69', '0.81', '0.52', '0.63', '0.53', '0.69', '0.74', '0.84\n']
# CELLS: ['29 01§46 Christ Walks on the Sea;02§12 Christ Stilling the Tempest;03§25 The Storm on the Sea;03§37 Mary and Martha', '0.61', '0.75', '0.48', '0.59', '0.62', '0.58', '0.37', '0.57', '0.7', '0.7', '0.63', '0.68', '0.84', '0.81', '0.79', '0.77', '0.78', '0.76', '0.81', '0.7', '0.79', '0.77', '0.63', '0.71', '0.9', '0.67', '0.79', '0.9', '1.0', '0.84', '0.85', '0.81', '0.79', '0.73', '0.7', '0.77', '0.68', '0.85', '0.46', '0.64', '0.7', '0.77', '0.61', '0.6', '0.57', '0.82', '0.74', '0.91', '0.78', '0.7', '0.82', '0.82', '0.53', '0.65', '0.68', '0.67', '0.71', '0.87\n']
# CELLS: ['30 01§52 “Christ the Son of the Living God”;04§18d The Jewish Elites Disbelieve;04§34 04§35 04§36 04§37 04§38 04§39 04§40 04§41 Jesus Teaches at the Last Supper', '0.41', '0.54', '0.53', '0.52', '0.41', '0.63', '0.36', '0.62', '0.43', '0.68', '0.6', '0.6', '0.71', '0.66', '0.74', '0.72', '0.7', '0.58', '0.79', '0.77', '0.58', '0.69', '0.6', '0.7', '0.87', '0.61', '0.61', '0.81', '0.84', '1.0', '0.79', '0.87', '0.83', '0.69', '0.76', '0.7', '0.47', '0.66', '0.5', '0.56', '0.76', '0.65', '0.65', '0.61', '0.54', '0.82', '0.56', '0.84', '0.76', '0.69', '0.59', '0.79', '0.58', '0.73', '0.68', '0.63', '0.65', '0.76\n']
# CELLS: ["31 01§53 Christ’s First Prophecy Concerning His Passion;01§88a On the Way to Gethsemane;02§25 The Leaven of the Pharisees;02§45a Jesus Predicts Peter's Denials;03§02a The Announcement of John the Baptist’s Birth;04§18a The Unbelief of Christ’s Brothers", '0.46', '0.6', '0.59', '0.65', '0.42', '0.6', '0.52', '0.53', '0.56', '0.62', '0.65', '0.64', '0.72', '0.61', '0.77', '0.66', '0.64', '0.57', '0.74', '0.72', '0.62', '0.75', '0.63', '0.75', '0.8', '0.56', '0.62', '0.91', '0.85', '0.79', '1.0', '0.85', '0.85', '0.74', '0.74', '0.55', '0.47', '0.8', '0.57', '0.69', '0.82', '0.8', '0.68', '0.42', '0.44', '0.84', '0.55', '0.86', '0.81', '0.79', '0.61', '0.86', '0.54', '0.64', '0.54', '0.72', '0.71', '0.9\n']
# CELLS: ['32 03§04 Mary’s Visit to Elizabeth;03§30 Peter’s Confession and Christ’s Answer;03§69 The Destruction of Jerusalem and the End of the World;04§08 John’s Second Testimony of Christ;04§52 The Test of Peter’s Love', '0.45', '0.57', '0.61', '0.54', '0.43', '0.72', '0.42', '0.66', '0.54', '0.72', '0.66', '0.5', '0.75', '0.69', '0.81', '0.68', '0.65', '0.61', '0.84', '0.83', '0.6', '0.65', '0.67', '0.76', '0.79', '0.6', '0.66', '0.89', '0.81', '0.87', '0.85', '1.0', '0.93', '0.67', '0.76', '0.68', '0.39', '0.73', '0.53', '0.64', '0.79', '0.7', '0.61', '0.55', '0.58', '0.89', '0.48', '0.83', '0.78', '0.74', '0.54', '0.75', '0.62', '0.63', '0.55', '0.65', '0.69', '0.77\n']
# CELLS: ['33 01§42b The Parable of the Tares; and Others Explained;01§54 The Transfiguration of Christ;02§28 The Transfiguration of Jesus;03§38 A Lesson in Prayer;03§56 Concerning the Kingdom of God and the Coming of Christ', '0.47', '0.48', '0.63', '0.57', '0.52', '0.78', '0.48', '0.61', '0.59', '0.71', '0.64', '0.66', '0.8', '0.69', '0.74', '0.71', '0.68', '0.64', '0.81', '0.77', '0.65', '0.73', '0.7', '0.72', '0.83', '0.69', '0.76', '0.85', '0.79', '0.83', '0.85', '0.93', '1.0', '0.72', '0.77', '0.69', '0.45', '0.79', '0.54', '0.67', '0.82', '0.74', '0.59', '0.55', '0.5', '0.91', '0.6', '0.76', '0.88', '0.85', '0.61', '0.84', '0.59', '0.58', '0.63', '0.68', '0.71', '0.81\n']
# CELLS: ['34 01§56a Christ Foretells His Passion;01§65 Christ Again Foretells His Passion;02§43a The Teachers of the Law Scheme;03§61 The Lord’s Third Prediction of His Passion', '0.65', '0.46', '0.6', '0.52', '0.48', '0.62', '0.47', '0.5', '0.49', '0.53', '0.51', '0.55', '0.84', '0.76', '0.63', '0.52', '0.65', '0.82', '0.84', '0.59', '0.56', '0.67', '0.51', '0.42', '0.81', '0.54', '0.68', '0.68', '0.73', '0.69', '0.74', '0.67', '0.72', '1.0', '0.51', '0.65', '0.57', '0.78', '0.51', '0.47', '0.9', '0.56', '0.46', '0.44', '0.42', '0.76', '0.58', '0.61', '0.67', '0.55', '0.61', '0.63', '0.54', '0.48', '0.5', '0.71', '0.47', '0.78\n']
# CELLS: ['35 01§60 On Marriage and Divorce;01§71 01§72 01§73 The Authority of Christ; The Parable of the Two Sons; The Parable of the Wicked Husbandmen;01§77 The Silencing of the Pharisees;02§38 The Question concerning Christ’s Authority;03§50 03§51 03§52 03§53 03§54 Parables and Teaching;04§23 Jesus the Good Shepherd', '0.37', '0.63', '0.71', '0.77', '0.49', '0.67', '0.6', '0.76', '0.56', '0.82', '0.87', '0.78', '0.54', '0.42', '0.78', '0.89', '0.81', '0.37', '0.61', '0.89', '0.78', '0.88', '0.87', '0.86', '0.62', '0.76', '0.64', '0.73', '0.7', '0.76', '0.74', '0.76', '0.77', '0.51', '1.0', '0.63', '0.62', '0.68', '0.76', '0.87', '0.57', '0.79', '0.81', '0.78', '0.45', '0.64', '0.6', '0.84', '0.83', '0.92', '0.73', '0.87', '0.72', '0.85', '0.81', '0.73', '0.96', '0.68\n']
# CELLS: ['36 01§68 Christ’s Entry into Jerusalem;02§36 Christ’s Entry into Jerusalem;03§65a Jesus Procures a Donkey', '0.78', '0.6', '0.67', '0.65', '0.78', '0.71', '0.48', '0.77', '0.74', '0.83', '0.71', '0.69', '0.77', '0.77', '0.74', '0.84', '0.88', '0.79', '0.77', '0.73', '0.74', '0.68', '0.65', '0.56', '0.81', '0.86', '0.79', '0.62', '0.77', '0.7', '0.55', '0.68', '0.69', '0.65', '0.63', '1.0', '0.7', '0.81', '0.45', '0.68', '0.66', '0.61', '0.57', '0.76', '0.76', '0.7', '0.74', '0.67', '0.72', '0.63', '0.77', '0.62', '0.67', '0.63', '0.82', '0.72', '0.65', '0.73\n']
# CELLS: ['37 01§69 Christ Visits the Temple;02§32 Jesus Blesses Little Children;02§50 Jesus before the Soldiers;03§65c Cleansing the Temple', '0.73', '0.58', '0.61', '0.71', '0.66', '0.59', '0.56', '0.62', '0.64', '0.66', '0.71', '0.75', '0.54', '0.7', '0.55', '0.81', '0.78', '0.65', '0.64', '0.55', '0.81', '0.78', '0.59', '0.46', '0.62', '0.72', '0.65', '0.53', '0.68', '0.47', '0.47', '0.39', '0.45', '0.57', '0.62', '0.7', '1.0', '0.73', '0.65', '0.58', '0.39', '0.61', '0.52', '0.79', '0.53', '0.5', '0.76', '0.64', '0.59', '0.63', '0.87', '0.64', '0.64', '0.65', '0.75', '0.68', '0.7', '0.63\n']
# CELLS: ['38 01§70 The Cursing of the Fig-Tree;02§37 The Miracle of the Fig-Tree', '0.83', '0.72', '0.73', '0.79', '0.76', '0.75', '0.63', '0.68', '0.82', '0.8', '0.77', '0.79', '0.83', '0.83', '0.79', '0.8', '0.83', '0.84', '0.84', '0.72', '0.81', '0.83', '0.7', '0.6', '0.86', '0.79', '0.79', '0.84', '0.85', '0.66', '0.8', '0.73', '0.79', '0.78', '0.68', '0.81', '0.73', '1.0', '0.58', '0.76', '0.74', '0.71', '0.63', '0.61', '0.61', '0.81', '0.79', '0.74', '0.83', '0.77', '0.8', '0.77', '0.69', '0.63', '0.68', '0.86', '0.73', '0.89\n']
# CELLS: ['39 01§74 The Parable of the Marriage Feast;02§39 The Parable of the Vineyard;03§66b Parable of the Wicked Tenants', '0.42', '0.45', '0.81', '0.79', '0.31', '0.77', '0.87', '0.66', '0.34', '0.6', '0.78', '0.63', '0.31', '0.43', '0.52', '0.68', '0.63', '0.37', '0.62', '0.63', '0.54', '0.73', '0.57', '0.57', '0.45', '0.57', '0.39', '0.54', '0.46', '0.5', '0.57', '0.53', '0.54', '0.51', '0.76', '0.45', '0.65', '0.58', '1.0', '0.61', '0.51', '0.62', '0.58', '0.75', '0.41', '0.57', '0.41', '0.59', '0.55', '0.71', '0.59', '0.66', '0.73', '0.68', '0.58', '0.68', '0.71', '0.58\n']
# CELLS: ['40 01§62 The Dangers of Riches;01§75 The Question Concerning Tribute;01§76 The Question of the Sadducees;02§07a New Wine into Old Wineskins;03§13b Jesus Heals Many;03§26 In the Country of the Gadarenes;03§67 The Pharisees Confounded', '0.55', '0.68', '0.73', '0.85', '0.68', '0.6', '0.67', '0.79', '0.79', '0.89', '0.9', '0.79', '0.57', '0.37', '0.85', '0.86', '0.85', '0.41', '0.52', '0.85', '0.78', '0.82', '0.92', '0.78', '0.57', '0.84', '0.66', '0.65', '0.64', '0.56', '0.69', '0.64', '0.67', '0.47', '0.87', '0.68', '0.58', '0.76', '0.61', '1.0', '0.5', '0.71', '0.78', '0.65', '0.48', '0.56', '0.62', '0.72', '0.86', '0.85', '0.7', '0.75', '0.68', '0.7', '0.75', '0.78', '0.89', '0.65\n']
# CELLS: ['41 01§86a Jesus Predicts Crucifixion;02§34a Jesus Turns Toward Jerusalem', '0.52', '0.37', '0.64', '0.54', '0.39', '0.71', '0.47', '0.56', '0.4', '0.52', '0.52', '0.5', '0.76', '0.69', '0.64', '0.54', '0.62', '0.72', '0.82', '0.67', '0.46', '0.62', '0.48', '0.51', '0.79', '0.55', '0.61', '0.71', '0.7', '0.76', '0.82', '0.79', '0.82', '0.9', '0.57', '0.66', '0.39', '0.74', '0.51', '0.5', '1.0', '0.61', '0.5', '0.43', '0.5', '0.87', '0.46', '0.67', '0.68', '0.63', '0.51', '0.69', '0.58', '0.51', '0.52', '0.65', '0.5', '0.86\n']
# CELLS: ['42 01§86c A Woman Anoints Jesus;02§43b The Anointing of Jesus;04§27 The Anointing of Jesus', '0.35', '0.59', '0.56', '0.59', '0.48', '0.58', '0.47', '0.52', '0.57', '0.65', '0.7', '0.72', '0.63', '0.54', '0.68', '0.78', '0.66', '0.47', '0.6', '0.61', '0.77', '0.78', '0.63', '0.77', '0.65', '0.64', '0.79', '0.76', '0.77', '0.65', '0.8', '0.7', '0.74', '0.56', '0.79', '0.61', '0.61', '0.71', '0.62', '0.71', '0.61', '1.0', '0.57', '0.62', '0.46', '0.62', '0.63', '0.83', '0.72', '0.81', '0.8', '0.8', '0.47', '0.59', '0.72', '0.57', '0.82', '0.78\n']
# CELLS: ["43 01§90b The Denial of Peter;02§48 The Denial of Peter;03§73a The Denial of Peter;04§44a Peter's First Denial", '0.4', '0.64', '0.61', '0.74', '0.5', '0.48', '0.54', '0.65', '0.51', '0.74', '0.75', '0.67', '0.44', '0.3', '0.71', '0.77', '0.74', '0.31', '0.49', '0.82', '0.63', '0.73', '0.8', '0.78', '0.56', '0.65', '0.44', '0.6', '0.61', '0.65', '0.68', '0.61', '0.59', '0.46', '0.81', '0.57', '0.52', '0.63', '0.58', '0.78', '0.5', '0.57', '1.0', '0.58', '0.43', '0.53', '0.56', '0.74', '0.73', '0.75', '0.54', '0.74', '0.74', '0.84', '0.69', '0.75', '0.78', '0.63\n']
# CELLS: ["44 01§93 The Crucifixion and Death of Christ;02§50 The Crucifixion and Death of Christ;04§47a The Jews Protest Pilate's Sign", '0.53', '0.55', '0.67', '0.68', '0.55', '0.7', '0.59', '0.75', '0.52', '0.74', '0.77', '0.71', '0.47', '0.55', '0.6', '0.87', '0.82', '0.49', '0.63', '0.71', '0.74', '0.75', '0.65', '0.57', '0.56', '0.77', '0.61', '0.5', '0.6', '0.61', '0.42', '0.55', '0.55', '0.44', '0.78', '0.76', '0.79', '0.61', '0.75', '0.65', '0.43', '0.62', '0.58', '1.0', '0.58', '0.54', '0.62', '0.67', '0.59', '0.69', '0.77', '0.65', '0.71', '0.74', '0.86', '0.61', '0.78', '0.57\n']
# CELLS: ['45 02§02a The Baptism and Temptation of Christ;03§10a The Baptism of Christ', '0.61', '0.33', '0.65', '0.62', '0.49', '0.68', '0.48', '0.78', '0.45', '0.69', '0.62', '0.33', '0.4', '0.66', '0.56', '0.66', '0.58', '0.57', '0.65', '0.58', '0.41', '0.36', '0.46', '0.51', '0.58', '0.61', '0.46', '0.47', '0.57', '0.54', '0.44', '0.58', '0.5', '0.42', '0.45', '0.76', '0.53', '0.61', '0.41', '0.48', '0.5', '0.46', '0.43', '0.58', '1.0', '0.62', '0.48', '0.55', '0.48', '0.39', '0.49', '0.47', '0.64', '0.6', '0.49', '0.47', '0.42', '0.53\n']
# CELLS: ['46 01§41b The Parable of the Sower Explained;01§57 01§58 01§59 The Greatest in the Kingdom of Heaven; How to Deal with an Erring Brother; Parable of the Unmerciful Servant;01§63 01§64 The Reward of the Apostles; Parable of the Laborers in the Vineyard;01§81 01§82 01§83 01§84 01§85 The Judgment of God upon Jerusalem and upon the World; The Need of Watchfulness; The Parable of the Ten Virgins; The Parable of the Talents; The Last Judgment;02§11b Teaching the Disciples by Means of Parables;03§72a The Walk to Gethsemane and the Agony;04§50 The Appearance to the Hidden Disciples', '0.6', '0.48', '0.66', '0.61', '0.51', '0.82', '0.54', '0.65', '0.55', '0.64', '0.59', '0.56', '0.74', '0.81', '0.71', '0.66', '0.68', '0.73', '0.87', '0.74', '0.55', '0.67', '0.56', '0.6', '0.86', '0.65', '0.61', '0.83', '0.82', '0.82', '0.84', '0.89', '0.91', '0.76', '0.64', '0.7', '0.5', '0.81', '0.57', '0.56', '0.87', '0.62', '0.53', '0.54', '0.62', '1.0', '0.56', '0.76', '0.79', '0.73', '0.59', '0.79', '0.64', '0.58', '0.54', '0.69', '0.58', '0.86\n']
# CELLS: ['47 01§56b Christ Pays the Temple-Tax;01§86d Judas Bargains for Jesus;02§17 Death of John the Baptist;03§27 The Woman with an Issue and the Daughter of Jairus;04§05 The Marriage at Cana', '0.69', '0.63', '0.45', '0.6', '0.84', '0.47', '0.39', '0.48', '0.79', '0.72', '0.58', '0.84', '0.72', '0.64', '0.67', '0.78', '0.81', '0.6', '0.55', '0.56', '0.88', '0.81', '0.61', '0.43', '0.78', '0.79', '0.73', '0.58', '0.74', '0.56', '0.55', '0.48', '0.6', '0.58', '0.6', '0.74', '0.76', '0.79', '0.41', '0.62', '0.46', '0.63', '0.56', '0.62', '0.48', '0.56', '1.0', '0.63', '0.74', '0.7', '0.82', '0.69', '0.43', '0.66', '0.76', '0.67', '0.66', '0.69\n']
# CELLS: ['48 01§87a The Passover Meal;01§91 The End of Judas;02§27a The Identity of the Son of Man;02§49a Jesus before Pilate;03§08 The Christ-Child in the Temple;03§33 Lessons in Humility;04§26 The Council concerning Christ’s Removal', '0.43', '0.72', '0.51', '0.64', '0.46', '0.55', '0.4', '0.62', '0.58', '0.69', '0.7', '0.64', '0.69', '0.62', '0.8', '0.81', '0.77', '0.53', '0.71', '0.8', '0.77', '0.78', '0.69', '0.8', '0.74', '0.62', '0.68', '0.87', '0.91', '0.84', '0.86', '0.83', '0.76', '0.61', '0.84', '0.67', '0.64', '0.74', '0.59', '0.72', '0.67', '0.83', '0.74', '0.67', '0.55', '0.76', '0.63', '1.0', '0.74', '0.77', '0.76', '0.84', '0.59', '0.79', '0.73', '0.61', '0.85', '0.85\n']
# CELLS: ['49 02§29 Casting Out an Unclean Spirit;02§33 The Rich Young Man;03§32 The Healing of the Epileptic Boy;03§60 Denying All for Christ’s Sake;04§16 04§17 Christ the Bread of Life', '0.61', '0.59', '0.71', '0.75', '0.73', '0.71', '0.61', '0.73', '0.78', '0.86', '0.79', '0.84', '0.73', '0.59', '0.84', '0.84', '0.82', '0.57', '0.68', '0.83', '0.76', '0.86', '0.87', '0.75', '0.83', '0.86', '0.73', '0.76', '0.78', '0.76', '0.81', '0.78', '0.88', '0.67', '0.83', '0.72', '0.59', '0.83', '0.55', '0.86', '0.68', '0.72', '0.73', '0.59', '0.48', '0.79', '0.74', '0.74', '1.0', '0.91', '0.7', '0.88', '0.65', '0.67', '0.74', '0.83', '0.79', '0.76\n']
# CELLS: ['50 02§40b The Sadducees Question Jesus About the Resurrection;03§36 The Good Samaritan;03§67 The Sadducees Confounded;04§50 The Appearance to Thomas', '0.47', '0.57', '0.71', '0.76', '0.62', '0.72', '0.64', '0.67', '0.67', '0.79', '0.81', '0.88', '0.61', '0.5', '0.75', '0.87', '0.79', '0.44', '0.61', '0.81', '0.81', '0.92', '0.83', '0.77', '0.7', '0.82', '0.69', '0.74', '0.7', '0.69', '0.79', '0.74', '0.85', '0.55', '0.92', '0.63', '0.63', '0.77', '0.71', '0.85', '0.63', '0.81', '0.75', '0.69', '0.39', '0.73', '0.7', '0.77', '0.91', '1.0', '0.74', '0.91', '0.66', '0.73', '0.8', '0.79', '0.9', '0.77\n']
# CELLS: ['51 01§61 Christ Blessing Little Children;01§89 The Betrayal and Arrest;02§08 Healing the Withered Hand;02§25 The Pharisees Ask for a Sign;02§46 The Capture of Jesus;03§72b Jesus Arrested;03§73b The Guards Mistreat Jesus', '0.62', '0.7', '0.55', '0.68', '0.73', '0.6', '0.47', '0.59', '0.72', '0.71', '0.72', '0.82', '0.68', '0.7', '0.65', '0.85', '0.85', '0.68', '0.64', '0.61', '0.91', '0.87', '0.66', '0.63', '0.7', '0.77', '0.84', '0.69', '0.82', '0.59', '0.61', '0.54', '0.61', '0.61', '0.73', '0.77', '0.87', '0.8', '0.59', '0.7', '0.51', '0.8', '0.54', '0.77', '0.49', '0.59', '0.82', '0.76', '0.7', '0.74', '1.0', '0.78', '0.54', '0.64', '0.8', '0.66', '0.81', '0.73\n']
# CELLS: ["52 01§47 A Lesson Concerning Defilement;02§20 02§21 Concerning Ceremonial Washings; Christ’s Denunciation of the Pharisees;03§05 The Birth of John the Baptist and Zechariah's Song;03§34a Opposition in Samaria;03§59 Christ Blesses Little Children", '0.43', '0.54', '0.64', '0.75', '0.52', '0.71', '0.57', '0.64', '0.55', '0.71', '0.73', '0.81', '0.6', '0.58', '0.68', '0.82', '0.75', '0.53', '0.67', '0.75', '0.72', '0.88', '0.74', '0.82', '0.77', '0.72', '0.68', '0.81', '0.82', '0.79', '0.86', '0.75', '0.84', '0.63', '0.87', '0.62', '0.64', '0.77', '0.66', '0.75', '0.69', '0.8', '0.74', '0.65', '0.47', '0.79', '0.69', '0.84', '0.88', '0.91', '0.78', '1.0', '0.63', '0.77', '0.72', '0.73', '0.83', '0.8\n']
# CELLS: ['53 03§02b Elizabeth Conceives;03§07 The Circumcision and Presentation of Christ;03§12 The Beginning of Christ’s Ministry and His Teaching in Nazareth;04§01 The Word Became Flesh;04§12 04§13 Jesus Defends Himself Against Jews Persecuting Him;04§26 Many Seek Jesus at the Festival', '0.61', '0.56', '0.85', '0.8', '0.47', '0.78', '0.73', '0.87', '0.47', '0.76', '0.84', '0.57', '0.4', '0.54', '0.64', '0.76', '0.72', '0.51', '0.68', '0.82', '0.52', '0.66', '0.77', '0.67', '0.55', '0.7', '0.42', '0.52', '0.53', '0.58', '0.54', '0.62', '0.59', '0.54', '0.72', '0.67', '0.64', '0.69', '0.73', '0.68', '0.58', '0.47', '0.74', '0.71', '0.64', '0.64', '0.43', '0.59', '0.65', '0.66', '0.54', '0.63', '1.0', '0.72', '0.63', '0.8', '0.67', '0.6\n']
# CELLS: ["54 03§28b Herod Hears about Jesus;03§41 Woes upon the Pharisees and Lawyers;04§18b Jesus Is Sought at the Festival;04§44c Peter's Second and Third Denials", '0.42', '0.58', '0.63', '0.78', '0.44', '0.57', '0.54', '0.72', '0.44', '0.76', '0.76', '0.67', '0.43', '0.42', '0.69', '0.82', '0.76', '0.37', '0.58', '0.81', '0.68', '0.77', '0.71', '0.72', '0.6', '0.66', '0.45', '0.63', '0.65', '0.73', '0.64', '0.63', '0.58', '0.48', '0.85', '0.63', '0.65', '0.63', '0.68', '0.7', '0.51', '0.59', '0.84', '0.74', '0.6', '0.58', '0.66', '0.79', '0.67', '0.73', '0.64', '0.77', '0.72', '1.0', '0.74', '0.68', '0.81', '0.63\n']
# CELLS: ['55 01§92 The Trial before Pilate;03§34b True Discipleship of Christ;03§65b Christ’s Entry into Jerusalem;03§74 The Trial before Pilate;04§04a The First Disciples of Jesus;04§44b The High Priest Questions Jesus', '0.52', '0.58', '0.58', '0.66', '0.66', '0.57', '0.49', '0.66', '0.63', '0.76', '0.73', '0.86', '0.62', '0.49', '0.66', '0.92', '0.88', '0.48', '0.56', '0.72', '0.83', '0.82', '0.72', '0.61', '0.67', '0.85', '0.73', '0.53', '0.68', '0.68', '0.54', '0.55', '0.63', '0.5', '0.81', '0.82', '0.75', '0.68', '0.58', '0.75', '0.52', '0.72', '0.69', '0.86', '0.49', '0.54', '0.76', '0.73', '0.74', '0.8', '0.8', '0.72', '0.63', '0.74', '1.0', '0.65', '0.84', '0.7\n']
# CELLS: ['56 03§46b Some Pharisees Warn Jesus;04§29 04§30 04§31 Some Greeks Seek Jesus but Many Disbelieve', '0.79', '0.69', '0.85', '0.84', '0.71', '0.72', '0.75', '0.76', '0.74', '0.85', '0.85', '0.81', '0.64', '0.63', '0.81', '0.78', '0.81', '0.64', '0.71', '0.8', '0.7', '0.85', '0.79', '0.63', '0.77', '0.82', '0.56', '0.69', '0.67', '0.63', '0.72', '0.65', '0.68', '0.71', '0.73', '0.72', '0.68', '0.86', '0.68', '0.78', '0.65', '0.57', '0.75', '0.61', '0.47', '0.69', '0.67', '0.61', '0.83', '0.79', '0.66', '0.73', '0.8', '0.68', '0.65', '1.0', '0.7', '0.74\n']
# CELLS: ['57 01§36b The Lord of the Sabbath - Healing;02§07b The Lord of the Sabbath;02§40a The Pharisees and Herodians Ask About Paying Taxes to Caesar;03§66a The Authority of Jesus;03§73c Christ before the Council of the Elders;04§20 04§21 Jesus the Light of the World;04§24a Christ’s Sermon at the Feast of Dedication', '0.42', '0.71', '0.64', '0.77', '0.56', '0.6', '0.55', '0.7', '0.66', '0.8', '0.86', '0.81', '0.58', '0.44', '0.77', '0.9', '0.84', '0.41', '0.57', '0.84', '0.88', '0.9', '0.85', '0.81', '0.57', '0.77', '0.7', '0.74', '0.71', '0.65', '0.71', '0.69', '0.71', '0.47', '0.96', '0.65', '0.7', '0.73', '0.71', '0.89', '0.5', '0.82', '0.78', '0.78', '0.42', '0.58', '0.66', '0.85', '0.79', '0.9', '0.81', '0.83', '0.67', '0.81', '0.84', '0.7', '1.0', '0.7\n']
# CELLS: ['58 02§42 Christ Foretells the Destruction of Jerusalem and the End of the World;02§44b The Celebration of the Passover;03§77 03§78 The Emmaus Disciples and the Last Appearances of Christ', '0.64', '0.65', '0.62', '0.68', '0.57', '0.65', '0.53', '0.56', '0.65', '0.62', '0.64', '0.73', '0.79', '0.75', '0.75', '0.74', '0.76', '0.71', '0.79', '0.7', '0.72', '0.79', '0.56', '0.6', '0.85', '0.68', '0.69', '0.84', '0.87', '0.76', '0.9', '0.77', '0.81', '0.78', '0.68', '0.73', '0.63', '0.89', '0.58', '0.65', '0.86', '0.78', '0.63', '0.57', '0.53', '0.86', '0.69', '0.85', '0.76', '0.77', '0.73', '0.8', '0.6', '0.63', '0.7', '0.74', '0.7', '1.0\n']

# %%
def generateTopEdgesFromCosineSimilarities(columnHeaders, cosineSimilaritiesRow):
    # 'ID\tSOURCE\tTARGET\tWEIGHT\n'
    cells = cosineSimilaritiesRow.split(',')
    edges = []
    edgeTuples = []
    columnHeadersWithoutIDColumn = columnHeaders[1:]
    source = cells[0]
    for count, cell in enumerate(cells):
        if count == 0:
            pass
        else:
            cell = cells[count]
            if float(cell) > 0:
                target = columnHeaders[count]
                if target == source:
                    pass
                else:
                    edgeTuples.append((source,target,float(cell)))
    edgeTuples.sort(key=lambda edgeTuple: edgeTuple[2])
    topEdgeValues = edgeTuples[-2:]
    topEdges = [edge for edge in edgeTuples if edge[2] == topEdgeValues[0][2] or edge[2] == topEdgeValues[1][2]]
    edges = ['\t'.join((f'{edge[0]}-{edge[1]}', edge[0], edge[1], str(edge[2]))) for edge in topEdges]
    print('Edges saved: ',len(edges))
    return edges
    

nodes = []
edges = []
edgesDict = dict()
with open(cosineSimilaritiesInputFilePath, 'r', encoding='utf8') as cosineCSVData:
    isFirstRow = True
    for line in cosineCSVData:
        if isFirstRow:
            columnHeaders = line.split(',')
            isFirstRow = False
        else:
            node = generateNodeFromCosineSimilarities(line)
            nodes.append(node)
            rowEdges = generateTopEdgesFromCosineSimilarities(columnHeaders, line)
            for edge in rowEdges:
                cells = edge.split('\t')
                targetAndSourceArray = [
                    cells[2], 
                    cells[1]
                ]
                if targetAndSourceArray[0] != targetAndSourceArray[1]:
                    targetAndSource = set(targetAndSourceArray)
                    pairIndex = '-'.join(targetAndSource)
                    edgesDict[pairIndex] = edge

with open('nodes_clusters_topEdgesOnly.tsv', 'a', encoding='utf8') as nodeFile:
    nodeFile.write('ID\tLABEL\tAVERAGE_SIMILARITY\n')
    for node in nodes:
        nodeFile.write(node)
        nodeFile.write('\n')
with open('edges_clusters_topEdgesOnly.tsv', 'a', encoding='utf8') as edgeFile:
    edgeFile.write('ID\tSOURCE\tTARGET\tWEIGHT\n')
    # for edge in prunedEdges:
    for count,edgePair in enumerate(edgesDict):
        edgeFile.write(edgesDict[edgePair])
        edgeFile.write('\n')
# Out:
# Edges saved:  3
# Edges saved:  3
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  3
# Edges saved:  2
# Edges saved:  3
# Edges saved:  2
# Edges saved:  3
# Edges saved:  4
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  3
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  3
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
# Edges saved:  2
